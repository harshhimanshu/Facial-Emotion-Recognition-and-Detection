# %%
import cv2

# %%
from deepface import DeepFace

# %%
img = cv2.imread('IMG_20201227_111858.jpg')

# %%
import matplotlib.pyplot as plt

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: emotion:   0%|                                                                           | 0/4 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 26ms/step
# Action: age:  25%|█████████████████▊                                                     | 1/4 [00:00<00:02,  1.37it/s]
# 1/1 [==============================] - 1s 1s/step
# Action: gender:  50%|██████████████████████████████████                                  | 2/4 [00:02<00:03,  1.51s/it]
# 1/1 [==============================] - 0s 270ms/step
# Action: race:  75%|████████████████████████████████████████████████████▌                 | 3/4 [00:03<00:00,  1.04it/s]
# 1/1 [==============================] - 0s 272ms/step
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:03<00:00,  1.17it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 1.119242102594125,
#   'disgust': 2.2267270413274233e-12,
#   'fear': 0.008496290398738188,
#   'happy': 0.00035063831459513934,
#   'sad': 0.08703541370059088,
#   'surprise': 0.00032264629927349623,
#   'neutral': 98.78454818909786},
#  'dominant_emotion': 'neutral',
#  'region': {'x': 369, 'y': 321, 'w': 1339, 'h': 1339},
#  'age': 28,
#  'gender': 'Man',
#  'race': {'asian': 32.88431167602539,
#   'indian': 18.826675415039062,
#   'black': 7.647985219955444,
#   'white': 9.397506713867188,
#   'middle eastern': 7.121370732784271,
#   'latino hispanic': 24.122151732444763},
#  'dominant_race': 'asian'}

# %%
predictions['dominant_emotion']
# Out:
# 'neutral'

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('Sad.jpeg')

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: emotion:   0%|                                                                           | 0/4 [00:00<?, ?it/s]
# 1/1 [==============================] - 1s 815ms/step
# Action: age:  25%|█████████████████▊                                                     | 1/4 [00:02<00:06,  2.18s/it]
# 1/1 [==============================] - 1s 604ms/step
# Action: gender:  50%|██████████████████████████████████                                  | 2/4 [00:02<00:02,  1.30s/it]
# 1/1 [==============================] - 1s 524ms/step
# Action: race:  75%|████████████████████████████████████████████████████▌                 | 3/4 [00:03<00:00,  1.02it/s]
# 1/1 [==============================] - 0s 392ms/step
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:03<00:00,  1.02it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 5.925675481557846,
#   'disgust': 2.386758524153265e-06,
#   'fear': 92.37385988235474,
#   'happy': 0.324074923992157,
#   'sad': 0.045048282481729984,
#   'surprise': 0.01512118469690904,
#   'neutral': 1.3162155635654926},
#  'dominant_emotion': 'fear',
#  'region': {'x': 59, 'y': 24, 'w': 130, 'h': 130},
#  'age': 39,
#  'gender': 'Man',
#  'race': {'asian': 44.18321251869202,
#   'indian': 1.4048226177692413,
#   'black': 0.7990770041942596,
#   'white': 39.03205096721649,
#   'middle eastern': 5.063578486442566,
#   'latino hispanic': 9.517254680395126},
#  'dominant_race': 'asian'}

# %%
img = cv2.imread('Disgust.png')

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: emotion:   0%|                                                                           | 0/4 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 28ms/step
# Action: age:  25%|█████████████████▊                                                     | 1/4 [00:00<00:01,  2.10it/s]
# 1/1 [==============================] - 0s 264ms/step
# Action: gender:  50%|██████████████████████████████████                                  | 2/4 [00:00<00:00,  2.54it/s]
# 1/1 [==============================] - 0s 272ms/step
# Action: race:  75%|████████████████████████████████████████████████████▌                 | 3/4 [00:01<00:00,  2.76it/s]
# 1/1 [==============================] - 0s 316ms/step
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.67it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 0.4817645065486431,
#   'disgust': 99.4779109954834,
#   'fear': 0.02021362306550145,
#   'happy': 5.46688960767483e-07,
#   'sad': 0.006328333256533369,
#   'surprise': 0.013548051356337965,
#   'neutral': 0.00023136472009355202},
#  'dominant_emotion': 'disgust',
#  'region': {'x': 20, 'y': 52, 'w': 135, 'h': 135},
#  'age': 32,
#  'gender': 'Man',
#  'race': {'asian': 0.9697486871181353,
#   'indian': 2.50733282504473,
#   'black': 0.2439877309188522,
#   'white': 41.44898849117619,
#   'middle eastern': 30.10478378591344,
#   'latino hispanic': 24.725162950177545},
#  'dominant_race': 'white'}

# %%
img = cv2.imread('Surprise.jpeg')

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: emotion:   0%|                                                                           | 0/4 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 24ms/step
# Action: age:  25%|█████████████████▊                                                     | 1/4 [00:00<00:01,  1.96it/s]
# 1/1 [==============================] - 0s 288ms/step
# Action: gender:  50%|██████████████████████████████████                                  | 2/4 [00:00<00:00,  2.37it/s]
# 1/1 [==============================] - 0s 356ms/step
# Action: race:  75%|████████████████████████████████████████████████████▌                 | 3/4 [00:01<00:00,  2.37it/s]
# 1/1 [==============================] - 0s 280ms/step
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.47it/s]
